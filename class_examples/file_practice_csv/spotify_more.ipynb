# %% [markdown]
# # Practicing file manipulation
# data source: https://www.kaggle.com/datasets/nelgiriyewithana/most-streamed-spotify-songs-2024

# %%
with open("kaggle_data/playlist.csv", "r") as f:
    spotify = []
    for line, text in enumerate(f):
        if line <= 0: 
            names = text
        if (line > 12885 and line < 12900):

            spotify.append(list(text.strip().split(",")))

# %%
# This is possible too! (and possibly better -- WHY?)
import csv
spotify_csv = []
with open('kaggle_data/playlist.csv', newline='') as csvfile:
    spotify2 = csv.reader(csvfile, quotechar='"')
    names_csv = next(spotify2) 
    for row in spotify2:
        spotify_csv.append(row)

# %%
# Out:
# ['track_name',
#  'track_add_date',
#  'track_add_time',
#  'multiple_artists_bool',
#  'name_of_artists',
#  'album_name',
#  'album_release_date',
#  'album_release_date_precision',
#  'number_of_tracks_in_album',
#  'position_in_playlist',
#  'track_duration_ms',
#  'track_popularity',
#  'track_explicit',
#  'images_path',
#  'data_collection_date']

# %%
type(spotify[0])
# Out:
# list

# %%
__[1][0]
# Out:
# 'End of Beginning'

# %% [markdown]
# # Tasks: we are going to work with the data file to pull out information!

# %%
# Task 1: dictionary to find how many times each song is in playlist
def songs_playlist(hits):
    hits_dict = {}
    for record in hits:
        song = record[0]
        if hits_dict.get(song, "NA") == "NA":
            
        else:
             
           
            
    return hits_dict

# %%
songs_playlist(spotify_csv)
# Out:
# {'Flowers': 233,
#  'Kill Bill': 270,
#  'TQG': 135,
#  'BESO': 117,
#  "Boy's a liar Pt. 2": 47,
#  'Ella Baila Sola': 183,
#  'Die For You (with Ariana Grande) - Remix': 112,
#  'As It Was': 269,
#  'La Bebe - Remix': 183,
#  "Creepin' (with The Weeknd & 21 Savage)": 151,
#  'Yandel 150': 87,
#  'Shakira: Bzrp Music Sessions, Vol. 53': 61,
#  'Calm Down (with Selena Gomez)': 178,
#  'Coco Chanel': 39,
#  'Like Crazy': 157,
#  'Anti-Hero': 199,
#  'All Of The Girls You Loved Before': 5,
#  'Unholy (feat. Kim Petras)': 58,
#  'Die For You': 204,
#  "I'm Good (Blue)": 134,
#  'La Bachata': 76,
#  'Last Night': 156,
#  'PRC': 84,
#  'Hey Mor': 55,
#  'Here With Me': 65,
#  'AMG': 70,
#  'Until I Found You (with Em Beihold) - Em Beihold Version': 65,
#  'Eyes Closed': 21,
#  'Starboy': 242,
#  'Another Love': 143,
#  'I Wanna Be Yours': 286,
#  'Arcángel: Bzrp Music Sessions, Vol. 54': 7,
#  'golden hour': 65,
#  'Quevedo: Bzrp Music Sessions, Vol. 52': 45,
#  'Escapism.': 35,
# ...

# %%
# Task 2: dictionary providing a list AND COUNT of songs an artist has

def artist_counts(dict_plays):
    artist_dict = {}
    for k,v in dict_plays.items():
        sub_d = {}
        #more code here
        artist_dict[k] = sub_d 
    return artist_dict

def artist_playlist(hits):
    artist_dict = {}
    for record in hits:
        #code here
           
            
    return artist_dict

# %%
arts = artist_playlist(spotify_csv)
arts

artist_counts(arts)
# Out:
# {"['Miley Cyrus']": {'songs': {'Angels Like You',
#    'Flowers',
#    'Used To Be Young'},
#   'count': 3},
#  "['SZA']": {'songs': {'Kill Bill', 'Saturn', 'Snooze'}, 'count': 3},
#  "['KAROL G', 'Shakira']": {'songs': {'TQG'}, 'count': 1},
#  "['ROSALÍA', 'Rauw Alejandro']": {'songs': {'BESO'}, 'count': 1},
#  "['PinkPantheress', 'Ice Spice']": {'songs': {"Boy's a Liar Pt. 2",
#    "Boy's a liar Pt. 2"},
#   'count': 2},
#  "['Eslabon Armado', 'Peso Pluma']": {'songs': {'Ella Baila Sola'},
#   'count': 1},
#  "['The Weeknd', 'Ariana Grande']": {'songs': {'Die For You (with Ariana Grande) - Remix'},
#   'count': 1},
#  "['Harry Styles']": {'songs': {'As It Was'}, 'count': 1},
#  "['Yng Lvcas', 'Peso Pluma']": {'songs': {'La Bebe - Remix'}, 'count': 1},
#  "['Metro Boomin', 'The Weeknd', '21 Savage']": {'songs': {"Creepin' (with The Weeknd & 21 Savage)"},
#   'count': 1},
#  "['Yandel', 'Feid']": {'songs': {'Yandel 150'}, 'count': 1},
# ...
